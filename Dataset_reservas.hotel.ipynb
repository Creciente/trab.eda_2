# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ruta =('/content/drive/MyDrive/Codificación de Dojo/Exámen/hotel_bookings.csv')

# %%
df= pd.read_csv(ruta)
# Out:
# <ipython-input-4-ab0b97da6487>:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv(ruta)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#   arrival_date_week_number  arrival_date_day_of_month  \
# 0                       27                          1
# 1                       27                          1
# 2                       27                          1
# 3                       27                          1
# 4                       27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month arrival_date_week_number  arrival_date_day_of_month  \
# 119385             August                       35                         30
# 119386             August                       35                         31
# 119387             August                       35                         31
# 119388             August                       35                         31
# 119389             August                       35                         29
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  object
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# 31904

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Eliminación de Duplicados

df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87486 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87486 non-null  object
#  1   is_canceled                     87486 non-null  int64
#  2   lead_time                       87486 non-null  int64
#  3   arrival_date_year               87486 non-null  int64
#  4   arrival_date_month              87486 non-null  object
#  5   arrival_date_week_number        87486 non-null  object
#  6   arrival_date_day_of_month       87486 non-null  int64
#  7   stays_in_weekend_nights         87486 non-null  int64
#  8   stays_in_week_nights            87486 non-null  int64
#  9   adults                          87486 non-null  int64
#  10  children                        87482 non-null  float64
#  11  babies                          87486 non-null  int64
# ...

# %%
# Datos Faltantes en 3 columnas; country, agent y en company
df['country'].value_counts()
# Out:
# PRT    27473
# GBR    10477
# FRA     8840
# ESP     7257
# DEU     5390
#        ...
# MMR        1
# BFA        1
# CYM        1
# MLI        1
# KHM        1
# Name: country, Length: 177, dtype: int64

# %%
df[df['country'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 30      Resort Hotel            0        118               2015
# 4127    Resort Hotel            1          0               2016
# 7092    Resort Hotel            1          8               2016
# 7860    Resort Hotel            1         39               2016
# 8779    Resort Hotel            1          0               2016
# ...              ...          ...        ...                ...
# 60651     City Hotel            1          0               2016
# 61244     City Hotel            1          0               2016
# 65907     City Hotel            1          0               2017
# 80830     City Hotel            0          4               2015
# 101488    City Hotel            0          1               2016
#
#        arrival_date_month arrival_date_week_number  arrival_date_day_of_month  \
# 30                   July                       27                          1
# ...

# %%
# Decido colocar a los Faltantes de la columna país como 'Otro'

df['country'].fillna('Otro', inplace = True)

# %%
df.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df[df['agent'].isnull()]
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 6       Resort Hotel            0          0               2015
# 18      Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 119124    City Hotel            0          0               2017
# 119151    City Hotel            0          0               2017
# 119166    City Hotel            0          0               2017
# 119215    City Hotel            0          2               2017
# 119248    City Hotel            0         22               2017
#
#        arrival_date_month arrival_date_week_number  arrival_date_day_of_month  \
# 0                    July                       27                          1
# ...

# %%
# Igualmente Reemplazaré los datos faltantes con '0.00', para que coincida con el diccionario que indica que es un float

df['agent'].fillna(0.00, inplace = True)

# %%
df.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Puesto que la columna company tiene demasiados datos faltantes y en el diccionario no hay descripcion, decido elimininarla.

df.drop(columns='company',inplace = True)
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
# Verificación de Incongruencias con el diccionario, todas las variables analizadas son las que posiblemente se ocuparán en las visualizaciones y
#las que directamente tienen incongruencias con el diccionario, estas son;  arrival_date_week_number, children y agent

df['hotel'].value_counts()
# Out:
# City Hotel      53428
# Resort Hotel    34058
# Name: hotel, dtype: int64

# %%
df['is_canceled'].value_counts()
# Out:
# 0    63459
# 1    24027
# Name: is_canceled, dtype: int64

# %%
df['arrival_date_week_number'].value_counts()
# Out:
# 33     2141
# 34     1978
# 32     1903
# 28     1849
# 18     1843
#        ...
# 50       84
# 3        80
# 51       79
# 1        66
# #27       1
# Name: arrival_date_week_number, Length: 107, dtype: int64

# %%
df['arrival_date_week_number']= df['arrival_date_week_number'].replace ('#27',27)

# %%
df['arrival_date_week_number'].value_counts()
# Out:
# 33    2141
# 34    1978
# 32    1903
# 28    1849
# 18    1843
#       ...
# 2       93
# 50      84
# 3       80
# 51      79
# 1       66
# Name: arrival_date_week_number, Length: 106, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87486 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87486 non-null  object
#  1   is_canceled                     87486 non-null  int64
#  2   lead_time                       87486 non-null  int64
#  3   arrival_date_year               87486 non-null  int64
#  4   arrival_date_month              87486 non-null  object
#  5   arrival_date_week_number        87486 non-null  object
#  6   arrival_date_day_of_month       87486 non-null  int64
#  7   stays_in_weekend_nights         87486 non-null  int64
#  8   stays_in_week_nights            87486 non-null  int64
#  9   adults                          87486 non-null  int64
#  10  children                        87482 non-null  float64
#  11  babies                          87486 non-null  int64
# ...

# %%
df['arrival_date_week_number']=df['arrival_date_week_number'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87486 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87486 non-null  object
#  1   is_canceled                     87486 non-null  int64
#  2   lead_time                       87486 non-null  int64
#  3   arrival_date_year               87486 non-null  int64
#  4   arrival_date_month              87486 non-null  object
#  5   arrival_date_week_number        87486 non-null  int64
#  6   arrival_date_day_of_month       87486 non-null  int64
#  7   stays_in_weekend_nights         87486 non-null  int64
#  8   stays_in_week_nights            87486 non-null  int64
#  9   adults                          87486 non-null  int64
#  10  children                        87482 non-null  float64
#  11  babies                          87486 non-null  int64
# ...

# %%
df['children'].value_counts()
# Out:
# 0.0     79117
# 1.0      4696
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: children, dtype: int64

# %%
# Eliminaré los 4 elementos faltantes de la columna children
df.dropna(subset=['children'], inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87482 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87482 non-null  object
#  1   is_canceled                     87482 non-null  int64
#  2   lead_time                       87482 non-null  int64
#  3   arrival_date_year               87482 non-null  int64
#  4   arrival_date_month              87482 non-null  object
#  5   arrival_date_week_number        87482 non-null  int64
#  6   arrival_date_day_of_month       87482 non-null  int64
#  7   stays_in_weekend_nights         87482 non-null  int64
#  8   stays_in_week_nights            87482 non-null  int64
#  9   adults                          87482 non-null  int64
#  10  children                        87482 non-null  float64
#  11  babies                          87482 non-null  int64
# ...

# %%
df['children']=df['children'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87482 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87482 non-null  object
#  1   is_canceled                     87482 non-null  int64
#  2   lead_time                       87482 non-null  int64
#  3   arrival_date_year               87482 non-null  int64
#  4   arrival_date_month              87482 non-null  object
#  5   arrival_date_week_number        87482 non-null  int64
#  6   arrival_date_day_of_month       87482 non-null  int64
#  7   stays_in_weekend_nights         87482 non-null  int64
#  8   stays_in_week_nights            87482 non-null  int64
#  9   adults                          87482 non-null  int64
#  10  children                        87482 non-null  int64
#  11  babies                          87482 non-null  int64
# ...

# %%
df['agent'].value_counts()
# Out:
# 9.0      28758
# 240.0    13036
# 0.0      12229
# 14.0      3348
# 7.0       3300
#          ...
# 257.0        1
# 291.0        1
# 93.0         1
# 483.0        1
# 449.0        1
# Name: agent, Length: 334, dtype: int64

# %%
df['agent']=df['agent'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87482 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87482 non-null  object
#  1   is_canceled                     87482 non-null  int64
#  2   lead_time                       87482 non-null  int64
#  3   arrival_date_year               87482 non-null  int64
#  4   arrival_date_month              87482 non-null  object
#  5   arrival_date_week_number        87482 non-null  int64
#  6   arrival_date_day_of_month       87482 non-null  int64
#  7   stays_in_weekend_nights         87482 non-null  int64
#  8   stays_in_week_nights            87482 non-null  int64
#  9   adults                          87482 non-null  int64
#  10  children                        87482 non-null  int64
#  11  babies                          87482 non-null  int64
# ...

# %% [markdown]
# ## Análisis del Problema
# ### ¿Cúales son los factores que podrían incrementar el número de reservas?

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df['is_canceled']=df['is_canceled'].replace('No',0)
df['is_canceled']=df['is_canceled'].replace('Si',1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87482 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           87482 non-null  object
#  1   is_canceled                     87482 non-null  int64
#  2   lead_time                       87482 non-null  int64
#  3   arrival_date_year               87482 non-null  int64
#  4   arrival_date_month              87482 non-null  object
#  5   arrival_date_week_number        87482 non-null  int64
#  6   arrival_date_day_of_month       87482 non-null  int64
#  7   stays_in_weekend_nights         87482 non-null  int64
#  8   stays_in_week_nights            87482 non-null  int64
#  9   adults                          87482 non-null  int64
#  10  children                        87482 non-null  int64
#  11  babies                          87482 non-null  int64
# ...

# %%
df['is_canceled'].value_counts()
# Out:
# 0    63459
# 1    24023
# Name: is_canceled, dtype: int64

# %%
size = df1
etiquetas = ['No Canceló','Canceló']
explotar = [0, 0.05]
fig = plt.figure(dpi=90)
ax1 = fig.add_subplot(1,1,1)
ax1.pie(size, labels=etiquetas, explode=explotar, autopct='%.2f%%', shadow = True, startangle=-90)
ax1.axis("equal")
plt.show()

# %% [markdown]
# ### ***Casi Un tercio de los pasajeros Cancela su reserva***

# %%
## La variable is_canceled contará los valores de cancelación
sns.barplot(x='is_canceled', y='arrival_date_month', data=df, errorbar=None)
plt.show()

# %% [markdown]
# # ##**Existe una tendencia a la cancelación entre los meses de Octubre y Marzo, con un leve repunte en el mes de Diciembre, seguramente por las festividades de fin de año. Pero, la cancelación aparentemente responde a una variable estacionaria.**

# %% [markdown]
# # ***En los Meses de Abril, Mayo, Junio con un Pick en Julio y Agosto es la mayor cantidad de reservas***

# %%
sns.barplot(x="is_canceled", y='arrival_date_month', hue="hotel", data=df ,errorbar=None)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # ##** La Variable Estacionaria Afecta al Resort, no asi al City Hotel.**

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        51625
# Offline TA/TO    13904
# Direct           11810
# Groups            4988
# Corporate         4225
# Complementary      703
# Aviation           227
# Name: market_segment, dtype: int64

# %%
sns.barplot(x='is_canceled', y='market_segment',hue='hotel', data=df, errorbar=None)
# Out:
# <Axes: xlabel='is_canceled', ylabel='market_segment'>

# %%
sns.barplot(x='is_repeated_guest', y='market_segment',hue='hotel', data=df, errorbar=None)
# Out:
# <Axes: xlabel='is_repeated_guest', ylabel='market_segment'>

# %% [markdown]
# ## En el contexto de fidelidad de los clientes, se puede apreciar que existe corporativos y los que corresponden al segmento aviacion y complementarios qu estan fidelizados , pero que requieren distintos tipos de atención. Por ejemplo, los pertenecientes a la aviación son pasajeros que tienen una alta cancelación, pero tambien repiten mucho su estadia en el hotel. Ovbiamente debido a su labor.

# %% [markdown]
# ***SE PROPONE HACER UNA ESTRATEGIA DE MARKETING PARA EL SEGMENTO ONLINE TA Y UNA CONVENCIONAL PARA EL SEGMENTO GROUPS, PUESTO QUE AMBOS TIENEN UNA ALTA CANCELACION Y UNA POCA EXPERIENCIA DE REPETICION EN LOS HOTELES***
